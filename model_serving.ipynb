# %%
# !pip3 install google-cloud-aiplatform --upgrade
# Out:
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.128.0-py2.py3-none-any.whl.metadata (46 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Using cached google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-cloud-aiplatform)
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-cloud-aiplatform)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 (from google-cloud-aiplatform)
#   Using cached protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: packaging>=14.3 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform) (25.0)
# Collecting google-cloud-storage<4.0.0,>=2.10.0 (from google-cloud-aiplatform)
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 (from google-cloud-aiplatform)
#   Using cached google_cloud_bigquery-3.38.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting google-cloud-resource-manager<3.0.0,>=1.3.3 (from google-cloud-aiplatform)
#   Using cached google_cloud_resource_manager-1.15.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting shapely<3.0.0 (from google-cloud-aiplatform)
#   Downloading shapely-2.1.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting google-genai<2.0.0,>=1.37.0 (from google-cloud-aiplatform)
#   Downloading google_genai-1.52.0-py3-none-any.whl.metadata (46 kB)
# Collecting pydantic<3 (from google-cloud-aiplatform)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing_extensions (from google-cloud-aiplatform)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting docstring_parser<1 (from google-cloud-aiplatform)
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting requests<3.0.0,>=2.18.0 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Downloading grpcio-1.76.0-cp314-cp314-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Using cached grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform)
#   Using cached cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.1 (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform)
#   Using cached google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.0.0 (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in ./.venv/lib/python3.14/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Collecting grpc-google-iam-v1<1.0.0,>=0.14.0 (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform)
#   Using cached grpc_google_iam_v1-0.14.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage<4.0.0,>=2.10.0->google-cloud-aiplatform)
#   Downloading google_crc32c-1.7.1.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anyio<5.0.0,>=4.8.0 (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Downloading websockets-15.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting idna>=2.8 (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting sniffio>=1.1 (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting certifi (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->google-cloud-aiplatform)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3->google-cloud-aiplatform)
#   Downloading pydantic_core-2.41.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3->google-cloud-aiplatform)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Downloading charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numpy>=1.21 (from shapely<3.0.0->google-cloud-aiplatform)
#   Downloading numpy-2.3.5-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Downloading google_cloud_aiplatform-1.128.0-py2.py3-none-any.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 71.0 MB/s  0:00:00
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Using cached google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Using cached cachetools-6.2.2-py3-none-any.whl (11 kB)
# Using cached google_cloud_bigquery-3.38.0-py3-none-any.whl (259 kB)
# Using cached google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Using cached google_cloud_resource_manager-1.15.0-py3-none-any.whl (397 kB)
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
# Downloading google_genai-1.52.0-py3-none-any.whl (261 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached grpc_google_iam_v1-0.14.3-py3-none-any.whl (32 kB)
# Downloading grpcio-1.76.0-cp314-cp314-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 65.5 MB/s  0:00:00
# Using cached grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp314-cp314-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 92.4 MB/s  0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading shapely-2.1.2-cp314-cp314-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.0 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading websockets-15.0.1-py3-none-any.whl (169 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading numpy-2.3.5-cp314-cp314-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 107.6 MB/s  0:00:00
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Building wheels for collected packages: google-crc32c
#   Building wheel for google-crc32c (pyproject.toml) ... done
#   Created wheel for google-crc32c: filename=google_crc32c-1.7.1-py3-none-any.whl size=13241 sha256=dd807154ef0d5789ebefef1800918d95ee1b8d61b6b15478b1b7c75deddbdf90
#   Stored in directory: /Users/ashwin/Library/Caches/pip/wheels/92/d4/e4/0df1d9978775ee957d83aeccb0cda14c1f1cd3a8d69a298a01
# Successfully built google-crc32c
# Installing collected packages: websockets, urllib3, typing_extensions, tenacity, sniffio, pyasn1, protobuf, numpy, idna, h11, google-crc32c, docstring_parser, charset_normalizer, certifi, cachetools, annotated-types, typing-inspection, shapely, rsa, requests, pydantic-core, pyasn1-modules, proto-plus, httpcore, grpcio, googleapis-common-protos, google-resumable-media, anyio, pydantic, httpx, grpcio-status, google-auth, grpc-google-iam-v1, google-genai, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, google-cloud-aiplatform
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40/40 [google-cloud-aiplatform]platform]ource-manager]
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 cachetools-6.2.2 certifi-2025.11.12 charset_normalizer-3.4.4 docstring_parser-0.17.0 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-aiplatform-1.128.0 google-cloud-bigquery-3.38.0 google-cloud-core-2.5.0 google-cloud-resource-manager-1.15.0 google-cloud-storage-3.6.0 google-crc32c-1.7.1 google-genai-1.52.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpc-google-iam-v1-0.14.3 grpcio-1.76.0 grpcio-status-1.76.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 numpy-2.3.5 proto-plus-1.26.1 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.5 pydantic-core-2.41.5 requests-2.32.5 rsa-4.9.1 shapely-2.1.2 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.2 typing_extensions-4.15.0 urllib3-2.5.0 websockets-15.0.1

# %%
from google.cloud import aiplatform

endpoint = aiplatform.Endpoint(
    endpoint_name="projects/queryhub-473901/locations/us-east1/endpoints/8391932339046842368"
)

# %%
test_mpg = [1.4838871833555929,
 1.8659883497083019,
 2.234620276849616,
 1.0187816540094903,
 -2.530890710602246,
 -1.6046416850441676,
 -0.4651483719733302,
 -0.4952254087173721,
 0.7746763768735953]

response = endpoint.predict([test_mpg])

print('API response: ', response)

print('Predicted MPG: ', response.predictions[0][0])
# Out:
# API response:  Prediction(predictions=[[15.5479088]], deployed_model_id='6402836639562858496', metadata=None, model_version_id='1', model_resource_name='projects/312485410499/locations/us-east1/models/7748948934239715328', explanations=None)
# Predicted MPG:  15.5479088
